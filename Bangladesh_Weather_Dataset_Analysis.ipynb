# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnob-Mitra/Machine-Learning-Works/blob/master/Bangladesh_Weather_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np
# %matplotlib inline

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-353fa6f0-c4fc-4164-a2ba-0ba926bdfe36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-353fa6f0-c4fc-4164-a2ba-0ba926bdfe36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Temp_and_rain.csv to Temp_and_rain.csv
# ...

# %%
df = pd.read_csv("Temp_and_rain.csv")
df
# Out:
#           tem  Month  Year       rain
# 0     16.9760      1  1901   18.53560
# 1     19.9026      2  1901   16.25480
# 2     24.3158      3  1901   70.79810
# 3     28.1834      4  1901   66.16160
# 4     27.8892      5  1901  267.21500
# ...       ...    ...   ...        ...
# 1375  28.0642      8  2015  512.12700
# 1376  28.1230      9  2015  353.86900
# 1377  26.8624     10  2015   81.59940
# 1378  23.1842     11  2015    4.60815
# 1379  18.7124     12  2015    5.97798
#
# [1380 rows x 4 columns]

# %%
df.head()
# Out:
#        tem  Month  Year      rain
# 0  16.9760      1  1901   18.5356
# 1  19.9026      2  1901   16.2548
# 2  24.3158      3  1901   70.7981
# 3  28.1834      4  1901   66.1616
# 4  27.8892      5  1901  267.2150

# %%
df.columns
# Out:
# Index(['tem', 'Month', 'Year', 'rain'], dtype='object')

# %%
df.describe()
# Out:
#                tem        Month        Year         rain
# count  1380.000000  1380.000000  1380.00000  1380.000000
# mean     25.066213     6.500000  1958.00000   203.275431
# std       3.682411     3.453304    33.20842   202.730898
# min      16.800600     1.000000  1901.00000     0.000000
# 25%      22.114125     3.750000  1929.00000    18.498850
# 50%      27.012950     6.500000  1958.00000   145.086000
# 75%      28.007850     9.250000  1987.00000   347.639500
# max      29.526000    12.000000  2015.00000  1012.020000

# %%
print('Total Entries: ', str(len(df)))
# Out:
# Total Entries:  1380

# %%
df['tem'].hist().plot()
# Out:
# []

# %%
df['rain'].hist().plot()
# Out:
# []

# %%
df.plot('Year','rain')

# %%
print(max(df['tem']))
# Out:
# 29.526

# %%
print(min(df['tem']))
# Out:
# 16.8006

# %%
df.loc[df.loc[:, 'tem'] == 29.526, :]
# Out:
#         tem  Month  Year     rain
# 940  29.526      5  1979  116.378

# %%
df.loc[df.loc[:, 'tem'] == 16.8006, :]
# Out:
#          tem  Month  Year    rain
# 924  16.8006      1  1978  0.6893

# %%
sns.countplot(x = 'tem', data = df)

# %%
df.plot.scatter(x = 'Year', y = 'rain', c = 'tem', colormap='viridis')
